# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =pd.read_excel('/content/Adidas US Sales Datasets.xlsx')
df
# Out:
#       Unnamed: 0   Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0            NaN          NaN  Adidas Sales Database                  NaN
# 1            NaN          NaN                    NaN                  NaN
# 2            NaN          NaN                    NaN                  NaN
# 3            NaN     Retailer            Retailer ID         Invoice Date
# 4            NaN  Foot Locker                1185732  2020-01-01 00:00:00
# ...          ...          ...                    ...                  ...
# 9647         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9648         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9649         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9650         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9651         NaN  Foot Locker                1185732  2021-02-22 00:00:00
#
#      Unnamed: 4     Unnamed: 5  Unnamed: 6               Unnamed: 7  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df =df.drop('Unnamed: 0',axis = 1)

# %%
df =df.drop([0,1,2 ],axis =0)

# %%
df
# Out:
#        Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 3        Retailer  Retailer ID         Invoice Date     Region          State
# 4     Foot Locker      1185732  2020-01-01 00:00:00  Northeast       New York
# 5     Foot Locker      1185732  2020-01-02 00:00:00  Northeast       New York
# 6     Foot Locker      1185732  2020-01-03 00:00:00  Northeast       New York
# 7     Foot Locker      1185732  2020-01-04 00:00:00  Northeast       New York
# ...           ...          ...                  ...        ...            ...
# 9647  Foot Locker      1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9648  Foot Locker      1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9649  Foot Locker      1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9650  Foot Locker      1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9651  Foot Locker      1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
# ...

# %%
df.columns = df.iloc[0,]

# %%
df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object', name=3)

# %%
df
# Out:
# 3        Retailer  Retailer ID         Invoice Date     Region          State  \
# 3        Retailer  Retailer ID         Invoice Date     Region          State
# 4     Foot Locker      1185732  2020-01-01 00:00:00  Northeast       New York
# 5     Foot Locker      1185732  2020-01-02 00:00:00  Northeast       New York
# 6     Foot Locker      1185732  2020-01-03 00:00:00  Northeast       New York
# 7     Foot Locker      1185732  2020-01-04 00:00:00  Northeast       New York
# ...           ...          ...                  ...        ...            ...
# 9647  Foot Locker      1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9648  Foot Locker      1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9649  Foot Locker      1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9650  Foot Locker      1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9651  Foot Locker      1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
# ...

# %%
df = df.drop(3,axis =0)

# %%
df
# Out:
# 3        Retailer Retailer ID         Invoice Date     Region          State  \
# 4     Foot Locker     1185732  2020-01-01 00:00:00  Northeast       New York
# 5     Foot Locker     1185732  2020-01-02 00:00:00  Northeast       New York
# 6     Foot Locker     1185732  2020-01-03 00:00:00  Northeast       New York
# 7     Foot Locker     1185732  2020-01-04 00:00:00  Northeast       New York
# 8     Foot Locker     1185732  2020-01-05 00:00:00  Northeast       New York
# ...           ...         ...                  ...        ...            ...
# 9647  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9648  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9649  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9650  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9651  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 4 to 9651
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   object
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   object
#  8   Units Sold        9648 non-null   object
#  9   Total Sales       9648 non-null   object
#  10  Operating Profit  9648 non-null   object
#  11  Operating Margin  9648 non-null   object
#  12  Sales Method      9648 non-null   object
# dtypes: object(13)
# memory usage: 980.0+ KB

# %%
df.describe()
# Out:
# 3          Retailer  Retailer ID         Invoice Date Region       State  \
# count          9648         9648                 9648   9648        9648
# unique            6            4                  724      5          50
# top     Foot Locker      1185732  2021-01-17 00:00:00   West  California
# freq           2637         5265                   77   2448         432
#
# 3           City                Product  Price per Unit  Units Sold  \
# count       9648                   9648            9648        9648
# unique        52                      6             146         361
# top     Portland  Men's Street Footwear              50         225
# freq         360                   1610             557         207
#
# 3       Total Sales  Operating Profit  Operating Margin Sales Method
# count          9648              9648           9648.00         9648
# unique         3512              6510            127.00            3
# ...

# %%
df.isnull().sum()
# Out:
# 3
# Retailer            0
# Retailer ID         0
# Invoice Date        0
# Region              0
# State               0
# City                0
# Product             0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Operating Margin    0
# Sales Method        0
# dtype: int64

# %%
df
# Out:
# 3        Retailer Retailer ID         Invoice Date     Region          State  \
# 4     Foot Locker     1185732  2020-01-01 00:00:00  Northeast       New York
# 5     Foot Locker     1185732  2020-01-02 00:00:00  Northeast       New York
# 6     Foot Locker     1185732  2020-01-03 00:00:00  Northeast       New York
# 7     Foot Locker     1185732  2020-01-04 00:00:00  Northeast       New York
# 8     Foot Locker     1185732  2020-01-05 00:00:00  Northeast       New York
# ...           ...         ...                  ...        ...            ...
# 9647  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9648  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9649  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9650  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9651  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
# ...

# %%
#visualization
plt.figure(figsize = (15,15))
pl = 1
for i in df.columns:
  if pl <= 13:
    plt.subplot(5,5,pl)
    sns.lineplot(df[i])
  pl +=1

plt.show()

# %%
#visualization
plt.figure(figsize = (15,15))
pl = 1
for i in df.columns:
  if pl <= 13:
    plt.subplot(5,5,pl)
    sns.boxplot(df[i])
  pl +=1

plt.show()

# %%
sns.pairplot(df)

# %%
df['Total Sales'] = df['Total Sales'].astype(int)

# %%
df['Units Sold'] = df['Units Sold'].astype(int)

# %%
df.groupby('Product')['Total Sales'].sum().nlargest(5)
# Out:
# Product
# Men's Street Footwear      208826167
# Women's Apparel            179038772
# Men's Athletic Footwear    153673673
# Women's Street Footwear    128002797
# Men's Apparel              123728529
# Name: Total Sales, dtype: int64

# %%
df.groupby('Product')['Units Sold'].sum().nsmallest(5)
# Out:
# Product
# Men's Apparel                306683
# Women's Athletic Footwear    317236
# Women's Street Footwear      392269
# Women's Apparel              433827
# Men's Athletic Footwear      435526
# Name: Units Sold, dtype: int64

# %%
df.groupby(['City','Product'])['Units Sold'].sum().nsmallest(5)
# Out:
# City         Product
# Omaha        Men's Apparel                1455
# Baltimore    Women's Athletic Footwear    1725
# Omaha        Women's Athletic Footwear    1761
# Minneapolis  Men's Apparel                1912
# Baltimore    Men's Apparel                1951
# Name: Units Sold, dtype: int64

# %%
df['Operating Margin'] = df['Operating Margin'].astype(float)

# %%
df1 = df[df['Operating Margin']>= .5]
df1[['City','Operating Margin']]
# Out:
# 3           City  Operating Margin
# 4       New York              0.50
# 10      New York              0.50
# 16      New York              0.50
# 22      New York              0.50
# 28      New York              0.50
# ...          ...               ...
# 9541  Burlington              0.51
# 9542  Burlington              0.52
# 9548  Burlington              0.51
# 9559  Burlington              0.50
# 9566  Burlington              0.51
#
# [2374 rows x 2 columns]

# %%
cate = df.select_dtypes(include ='object').columns
cate
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Operating Profit', 'Sales Method'],
#       dtype='object', name=3)

# %%
from sklearn.preprocessing import LabelEncoder
a = LabelEncoder()
for i in cate:
  df[i] = a.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 4 to 9651
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   int64
#  1   Retailer ID       9648 non-null   int64
#  2   Invoice Date      9648 non-null   int64
#  3   Region            9648 non-null   int64
#  4   State             9648 non-null   int64
#  5   City              9648 non-null   int64
#  6   Product           9648 non-null   int64
#  7   Price per Unit    9648 non-null   int64
#  8   Units Sold        9648 non-null   int64
#  9   Total Sales       9648 non-null   int64
#  10  Operating Profit  9648 non-null   int64
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   int64
# dtypes: float64(1), int64(12)
# memory usage: 980.0 KB

# %%
crr = df.corr()

# %%
plt.figure(figsize = (15,15))
sns.heatmap(crr,annot =True)
# Out:
# <Axes: xlabel='3', ylabel='3'>

# %%
df
# Out:
# 3     Retailer  Retailer ID  Invoice Date  Region  State  City  Product  \
# 4            1            1             0       1     31    35        2
# 5            1            1             1       1     31    35        1
# 6            1            1             2       1     31    35        5
# 7            1            1             3       1     31    35        4
# 8            1            1             4       1     31    35        0
# ...        ...          ...           ...     ...    ...   ...      ...
# 9647         1            1           382       1     28    30        0
# 9648         1            1           382       1     28    30        3
# 9649         1            1           411       1     28    30        2
# 9650         1            1           411       1     28    30        1
# 9651         1            1           411       1     28    30        5
#
# 3     Price per Unit  Units Sold  Total Sales  Operating Profit  \
# ...
